# %% [markdown]
# Here I just investigate the use of a Laplacian pyramid which was mentioned in some other papers

# %%
import numpy as np 
import cv2 
import matplotlib.pyplot as plt
image = cv2.imread('edgeflower.png',0)

# %%
gaussian = []  

gaussian_layer= image.copy()

# %%
for i in range(6):
    gaussian_layer = cv2.pyrDown(gaussian_layer)
    gaussian.append(gaussian_layer)    
    plt.imshow(cv2.cvtColor(gaussian_layer, cv2.COLOR_BGR2RGB))
    plt.title('Gaussian Layer -{}'.format(i))
    plt.show();

# %%
laplacian = [gaussian[-1]]

# %%
for i in range(5,0,-1):
    size = (gaussian[i - 1].shape[1], gaussian[i - 1].shape[0])
    gaussian_expanded = cv2.pyrUp(gaussian[i], dstsize=size)
    laplacian_layer = cv2.subtract(gaussian[i-1], gaussian_expanded)
    laplacian.append(laplacian_layer)
    plt.imshow(cv2.cvtColor(laplacian_layer, cv2.COLOR_BGR2RGB))
    plt.title('laplacian layer -{}'.format(i))
    plt.show();
